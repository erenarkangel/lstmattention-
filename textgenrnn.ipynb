# %%
import textgenrnn
from textgenrnn import textgenrnn

import pandas as pd

#pd.read_csv('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',header=None,sep=",")

df = pd.read_csv('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt', sep=",")

# %%
df.iloc[2100]
# Out:
# 30403109418 30501110537 30501111032           0    30102100917 30302105401 30301104914 30302105401
# Name: 2100, dtype: object

# %%
textgen = textgenrnn()
textgen.generate()
# Out:
# My first time that were going to be more than this subreddit in a show of the state recording to a company to a distance in your family likely to see the recently and what are the competitions in depression about what it's really the best programming in the same school is a bit of the state with a

# %%
textgen.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt', num_epochs=1,max_length = 2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jv/2_fp3b717yl0vd8xbytqhz300000gn/T/ipykernel_65670/3406172907.py in <module>
# ----> 1 textgen.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt', num_epochs=1,max_length = 2)
#
# NameError: name 'textgen' is not defined

# %%
a=textgen.generate(5)
# Out:
#  20%|█████████████                                                    | 1/5 [00:01<00:07,  1.85s/it]
# 30101100121 30102100916 30101100616           0
#  40%|██████████████████████████                                       | 2/5 [00:03<00:05,  1.80s/it]
# 30101100336 30101100116 30101100407 30101100115
#  60%|███████████████████████████████████████                          | 3/5 [00:05<00:03,  1.80s/it]
# 30303106323 30303106513 30305107321 30302105614
#  80%|████████████████████████████████████████████████████             | 4/5 [00:07<00:01,  1.81s/it]
# 30101100121 30101100321 30101100517 30101100316
# 100%|█████████████████████████████████████████████████████████████████| 5/5 [00:09<00:00,  1.81s/it]
# 30101100111 30101100316 30101100111           0

# %%
textgen1n1 = textgenrnn()
textgen2n1 = textgenrnn()
textgen3n1 = textgenrnn()
textgen4n1 = textgenrnn()

textgen1n1.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True, num_epochs=100,word_level=True,max_length=1)
#textgen2n1.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True, num_epochs=100,word_level=True,max_length=2)
#textgen3n1.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True, num_epochs=100,word_level=True,max_length=3)
#textgen4n1.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True, num_epochs=100,word_level=True,max_length=4)
#textgen2.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt', num_epochs=100,word_level=True,max_length=2)
# Out:
# 5,355 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 26,775 word sequences.
# Epoch 1/100
# 207/209 [============================>.] - ETA: 0s - loss: 5.0728####################
# Temperature: 0.2
# ####################
# ...
# 1/1 [==============================] - 0s 21ms/step
# 30301105124 0
#
# 1/1 [==============================] - 0s 20ms/step
#
#
# 1/1 [==============================] - 0s 19ms/step
#
#
# ####################
# Temperature: 0.5
# ####################
# ...
# 1/1 [==============================] - 0s 21ms/step
# 30201102227 0
#
# ...
# 1/1 [==============================] - 0s 19ms/step
# 30501110703 0
#
# ...
# 1/1 [==============================] - 0s 19ms/step
# 30302105306 0 0
#
# ####################
# Temperature: 1.0
# ####################
# ...
# 1/1 [==============================] - 0s 20ms/step
# 30202102728
#
# ...
# 1/1 [==============================] - 0s 20ms/step
# 30101100101 30103102031 30101100129 30404110324 30103101518 0
#
# ...

# %%
#callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

textgen3n1deney = textgenrnn()
#textgen2.save('200epoch.hdf5')
#textgen2n1.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True, num_epochs=20,word_level=True,max_length=2,dropout=0.2,rnn_size=128)
textgen3n1deney.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True,
                           num_epochs=5,word_level=True,dropout=0.1,max_length=3,rnn_size=50,batch_size=5,
                          rnn_layers=2,dim_embeddings=20)
#textgen4n1.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True, num_epochs=20,word_level=True,max_length=4,dropout=0.2,rnn_size=128)


#gen_epochs
#rnn_bidirectional


## dropout 0.2 rnn size 32 embedding 10 epoch 10 did not work very bad
# Out:
# 5,355 texts collected.
# Training new model w/ 2-layer, 50-cell LSTMs
# Training on 26,775 word sequences.
# Epoch 1/5
# 5350/5355 [============================>.] - ETA: 0s - loss: 4.4527####################
# Temperature: 0.2
# ####################
# ...
# 1/1 [==============================] - 0s 21ms/step
# 30503113111 30503111913 30503113111 0
#
# ...
# 1/1 [==============================] - 0s 23ms/step
# 30101100121 30101100407 30101100121 0
#
# ...
# 1/1 [==============================] - 0s 23ms/step
# 30101100121 30101100407 30101100121 0
#
# ####################
# Temperature: 0.5
# ####################
# ...
# 1/1 [==============================] - 0s 23ms/step
# 30101100318 30101100407 30101100318 0
#
# ...
# 1/1 [==============================] - 0s 23ms/step
# 30501110531 30501110536 0
#
# ...
# 1/1 [==============================] - 0s 20ms/step
# 30102101214 30102101325 30102101214 0
#
# ####################
# Temperature: 1.0
# ####################
# ...

# %%
textgen1n1deney.train_from_file('/Users/erensmacbook/Downloads/SeqGAN-PyTorch-master-2/a.txt',new_model=True,
                           num_epochs=5,word_level=True,dropout=0.3,max_length=4,rnn_size=32,batch_size=5,
                          rnn_layers=2,dim_embeddings=10)
# Out:
# 5,355 texts collected.
# Training new model w/ 2-layer, 32-cell LSTMs
# Training on 26,775 word sequences.
# Epoch 1/5
# 5348/5355 [============================>.] - ETA: 0s - loss: 4.6344####################
# Temperature: 0.2
# ####################
# ...
# 1/1 [==============================] - 0s 36ms/step
# 30302105323 30501110531 30101100114 0
#
# ...
# 1/1 [==============================] - 0s 22ms/step
# 30402108629 30501110531 30402108629 0
#
# ...
# 1/1 [==============================] - 0s 20ms/step
# 30102101107 30501110531 30102101107 0
#
# ####################
# Temperature: 0.5
# ####################
# ...
# 1/1 [==============================] - 0s 20ms/step
# 30302105323 30102101211 30302105323 0
#
# ...
# 1/1 [==============================] - 0s 19ms/step
# 30101100114 30501110531 30101100114 0
#
# ...
# 1/1 [==============================] - 0s 24ms/step
# 30303106416 30102100728 0 0
#
# ####################
# Temperature: 1.0
# ####################
# ...

# %%
#sensivit

# %%
#textgen2n1.generate(5,temperature=1,return_as_list=True)

# %%
exp1=textgen1n1deney.generate(1200,temperature=0.9,return_as_list=True)
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step
# ...
# ...
#  97%|█████████████████████████████████████▉ | 1169/1200 [05:57<00:09,  3.16it/s]

# %%
#textgen4n1.generate(10,temperature=1,return_as_list=True)

# %%
#textgen3n1.generate(20,temperature=1.5,return_as_list=True) ## max length artırmak sonucları iyilestirdi

# %%
list_of_list=[]

for i in exp1:
    x = i.split()
    list_of_list.append(x)

list_of_list=[x for x in list_of_list if len(x)==4]
#cols=list(map(str, range(0,3)))
#rnn_sample1.columns = cols
exp2_mb= pd.DataFrame.from_records(list_of_list)

# %%
exp1_4503.to_csv('/Users/erensmacbook/exp1_4503.csv')

# %%
exp1
# Out:
# ['30403109210 30403109203 30403109210 30403109203',
#  '30304107111 30304107116 30304107111 0',
#  '30101100124 30302105820 30101100124 0',
#  '30101100505 30101100407 30101100505 0',
#  '30204104213 30204104408 30204104213 0',
#  '30503113111 30501110513 30503113111 0',
#  '30502111731 30502111412 30502111731 0',
#  '30402108629 30402108629 0 0',
#  '30202103221 30202102820 30202103221 30202103225',
#  '30303106505 30303106511 30303106505 0',
#  '30302105225 30203103603 30306107905 30501111213',
#  '30101100101 30102100738 30101100101 30102101302',
#  '30402108629 30402108629 30402108629',
#  '30101100329 30102100728 30101100329 0',
#  '30204104522 30501111001 30204104522 0',
#  '30101100140 30102100728 30101100140 0',
#  '30304107112 30304107116 30304107112 30302105812',
#  '30101100329 30501110530 30101100329 0',
#  '30302105612 30304106701 30302105612 0',
#  '30101100430 30103101824 30101100430 30102100727',
#  '30404110322 30504113210 30404110322 0',
# ...

# %%
list1=textgen2.generate(1000,temperature=0.7,return_as_list=True)
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step
# ...
# ...
# 100%|███████████████████████████████████████| 1000/1000 [04:19<00:00,  3.85it/s]

# %%
list2=textgen2.generate(1000,temperature=1,return_as_list=True)
# Out:
# 100%|███████████████████████████████████████████████████████████| 1000/1000 [29:52<00:00,  1.79s/it]

# %%
list1
# Out:
# ['30102100926 30101100403 0 0',
#  '30501110611 30501111008 30501111014 30501110611',
#  '30101100411 30101100407 30101100411 0',
#  '30101100612 30501110531 30101100612 0',
#  '30306107711 30306107705 30306107711 30501111001',
#  '30403109402 30403109426 30403109418 30403109402',
#  '30101100416 30101100334 30101100416 30101100442',
#  '30101100601 30101100106 30101100407 30302105807',
#  '30404110322 30501111108 30404110322 0',
#  '30202102731 30501110519 30202102731 0',
#  '30404110322 30203103603 0 0',
#  '30301105127 30501111115 30301105127 0',
#  '30401108114 30403109426 30401108114 0',
#  '30402109001 30403109615 30403109433 30402109001',
#  '30101100603 30102101234 30101100603 0',
#  '30301104804 30305107632 30301104804 0',
#  '30101100428 30103101701 30101100442 30101100428',
#  '30203103807 30501110518 30203103807 0',
#  '30504113420 30504113731 30504113420 0',
#  '30501111213 30501111202 30501110707 30501111213',
#  '30101100401 30102100738 30101100401 0',
# ...

# %%
txt = list1[2]

x = txt.split()

print(x)
# Out:
# ['30101100121', '30101100407', '30101100121', '0']

# %%
def create_df_from_seq():

# %%
list_of_list=[]

for i in list1:
    x = i.split()
    list_of_list.append(x)

cols=list(map(str, range(0,7)))
rnn_sample1.columns = cols
rnn_sample1=rnn_sample1[['0','1','2','3']] 

rnn_sample1=pd.DataFrame.from_records(list_of_list)

# %%
cols=list(map(str, range(0,7)))
rnn_sample1.columns = cols
rnn_sample1=rnn_sample1[['0','1','2','3']]

# %%
rnn_sample1=pd.DataFrame.from_records(list_of_list)

# %%
rnn_sample2=pd.DataFrame.from_records(list_of_list)
cols=list(map(str, range(0,5)))
rnn_sample2.columns = cols
rnn_sample2=rnn_sample2.drop(['4'],axis=1)
rnn_sample2
# Out:
#                0            1            2            3
# 0    30103102106  30103102036  30103102106            0
# 1    30503112613  30503112620  30503112613  30503112613
# 2    30404109803  30503112810  30404109801            0
# 3    30102100809  30501110531  30102100809            0
# 4    30101100422  30503112708  30101100422  30101100605
# ..           ...          ...          ...          ...
# 995  30304107002  30304107016  30305107632            0
# 996  30401108117  30403109615  30401108117            0
# 997  30101100127  30101100615  30502111301  30103102112
# 998  30202102731  30202102812  30202102731            0
# 999  30202102702  30203103603            0            0
#
# [1000 rows x 4 columns]

# %%
rnn_sample1.to_csv('/Users/erensmacbook/rnn_sample1word.csv')

# %%
rnn_sample2=rnn_sample2.dropna()
rnn_sample2.to_csv('/Users/erensmacbook/rnn_sample2.csv')

# %%
list2[31].split()
# Out:
# ['30101100602', '30101100435', '30101100602', '0']

# %%
list3=textgen2.generate(5300,temperature=0.5,return_as_list=True)
# Out:
# 100%|█████████████████████████████████████████████████████████| 5300/5300 [2:37:33<00:00,  1.78s/it]

# %%
#texgen1 ...

# %%
rnn_sample3=pd.DataFrame.from_records(list_of_list)

# %%
cols=list(map(str, range(0,5)))
rnn_sample3.columns = cols
rnn_sample3=rnn_sample3.drop(['4'],axis=1)
rnn_sample3
# Out:
#                 0            1            2            3
# 0     30101100129  30303106511  30101100129  30101100116
# 1     30101100124  30101100112  30101100124            0
# 2     30101100422  30101100407  30101100422            0
# 3     30101100324  30102100728  30101100324            0
# 4     30101100401  30101100407  30101100403  30101100401
# ...           ...          ...          ...          ...
# 5295  30302105224  30302105208  30302105224            0
# 5296  30101100125  30101100407  30101100125            0
# 5297  30101100102  30101100505  30101100102            0
# 5298  30102100926  30102100934  30102100926            0
# 5299  30301105124  30301105142  30301105124  30502111310
#
# [5300 rows x 4 columns]

# %%
rnn_sample3=rnn_sample3.dropna()
rnn_sample3.to_csv('/Users/erensmacbook/rnn_sample3.csv')

# %%
list4=textgen2.generate(5300,temperature=0.4,return_as_list=True)
# Out:
# 100%|████████████████████████████████████████████████████████| 5300/5300 [17:03:09<00:00, 11.58s/it]

# %%
rnn_sample4=pd.DataFrame.from_records(list_of_list)

# %%
cols=list(map(str, range(0,5)))
rnn_sample4.columns = cols
rnn_sample4=rnn_sample4.drop(['4'],axis=1)
rnn_sample4
# Out:
#                 0            1            2            3
# 0     30401108117  30401108111  30401108117  30401108115
# 1     30101100420  30101100442  30101100420            0
# 2     30401108412  30401108403  30401108412  30401108115
# 3     30101100408  30102100728  30101100408            0
# 4     30101100420  30101100442  30101100420            0
# ...           ...          ...          ...          ...
# 5295  30101100121  30101100120  30101100121  30101100112
# 5296  30403109506  30403109518  30501110617  30403109506
# 5297  30402108634  30403109430  30401108220  30401108111
# 5298  30101100602  30101100606  30102100740  30101100602
# 5299  30304107112  30304107116  30304107112  30304106905
#
# [5300 rows x 4 columns]

# %%
rnn_sample4.to_csv('/Users/erensmacbook/rnn_sample4.csv')

# %%
list5=textgen2.generate(5000,temperature=0.8,return_as_list=True)
# Out:
# 100%|█████████████████████████████████████████████████████████| 5000/5000 [6:21:59<00:00,  4.58s/it]

# %%
cols=list(map(str, range(0,4)))

# %%
rnn_sample5=pd.DataFrame.from_records(list_of_list)

# %%
cols=list(map(str, range(0,8)))
rnn_sample5.columns = cols
rnn_sample5=rnn_sample5.drop(['4','5','6','7'],axis=1)
rnn_sample5
# Out:
#                 0            1            2            3
# 0     30101100116  30203103815  30101100116            0
# 1     30101100403  30101100407  30101100403            0
# 2     30404110322  30501110531  30404110322            0
# 3     30504113208  30501110541  30501110621  30504113218
# 4     30102100944  30501110531  30102100944            0
# ...           ...          ...          ...          ...
# 4995  30202103221  30403109615  30202103221            0
# 4996  30102101322  30103102137  30102101322            0
# 4997  30402108805  30403109416  30504113731  30402108903
# 4998  30503112806  30501110607  30501110531  30503112806
# 4999  30101100418  30103101517  30101100418            0
#
# [5000 rows x 4 columns]

# %%
rnn_sample5.to_csv('/Users/erensmacbook/rnn_sample5.csv')

# %%
list6=textgen2.generate(500,temperature=0.8,return_as_list=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████| 500/500 [14:53<00:00,  1.79s/it]

# %%
rnn_sample6=pd.DataFrame.from_records(list_of_list)

# %%
cols=list(map(str, range(0,5)))
rnn_sample6.columns = cols
rnn_sample6=rnn_sample6.drop(['4'],axis=1)
rnn_sample6
# Out:
#                0            1            2            3
# 0    30501110703  30503111913  30501110703            0
# 1    30102101107  30101100434  30101100407  30101100407
# 2    30203104025  30102101212  30203104025            0
# 3    30202102731  30501110536  30202102731            0
# 4    30303106103  30202103005  30303106103            0
# ..           ...          ...          ...          ...
# 495  30303106222  30303106511  30303106341  30303106020
# 496  30101100115  30101100112  30101100115            0
# 497  30101100408  30101100442  30101100408            0
# 498  30402109001  30402109007  30403109418  30403109416
# 499  30101100408  30301105142  30101100408            0
#
# [500 rows x 4 columns]

# %%
rnn_sample6.to_csv('/Users/erensmacbook/rnn_sample6.csv')

# %%
list50k=textgen2.generate(50000,temperature=0.8,return_as_list=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 50000/50000 [24:28:05<00:00,  1.76s/it]

# %%
rnn50k=pd.DataFrame.from_records(list_of_list)

# %%
cols=list(map(str, range(0,8)))
rnn50k.columns = cols
rnn50k=rnn50k.drop(['4','5','6','7'],axis=1)
rnn50k
# Out:
#                  0            1            2            3
# 0      30501110928  30501110928  30501110930  30501110928
# 1      30306107807  30306107808  30306107807  30306107808
# 2      30103101620  30102100713  30103101620            0
# 3      30402108630  30402108614  30402109004  30402108626
# 4      30402108612  30305107625  30302105102  30501111213
# ...            ...          ...          ...          ...
# 49995  30502111731  30501111014  30502111731            0
# 49996  30102100924  30501110617  30102100924            0
# 49997  30503112613  30501110531  30503112613            0
# 49998  30202103307  30202102706  30202103225  30202103307
# 49999  30302105612  30302105618  30302105612  30302105312
#
# [50000 rows x 4 columns]

# %%
rnn50k.to_csv('/Users/erensmacbook/downloads/rnn50k.csv')

# %%
texts = ['eren','eren','er','erken','ar','gil','arkan','eren arkangil','uf','whore','token','run','run away'
        'eren arka','eren hakang','erhangil','erkan','erkangil','abcdefghjklmneoprstjkwyuıol245']

context_labelss = ('valve','valve')*18
textgencc.reset()
textgencc.train_new_model(texts,context_labels=context_labelss,max_length=4, gen_epochs=1, num_epochs=1)
# Out:
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 150 character sequences.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/jv/2_fp3b717yl0vd8xbytqhz300000gn/T/ipykernel_30277/151564904.py in <module>
#       4 context_labelss = ('valve','valve')*18
#       5 textgencc.reset()
# ----> 6 textgencc.train_new_model(texts,context_labels=context_labelss,max_length=4, gen_epochs=1, num_epochs=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/textgenrnn/textgenrnn.py in train_new_model(self, texts, context_labels, num_epochs, gen_epochs, batch_size, dropout, train_size, validation, save_epochs, multi_gpu, **kwargs)
#     328             json.dump(self.config, outfile, ensure_ascii=False)
#     329
# --> 330         self.train_on_texts(texts, new_model=True,
#     331                             via_new_model=True,
# ...

# %%
list50k=textgen2.generate(150000,temperature=0.8,return_as_list=True)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████| 150000/150000 [246:36:57<00:00,  5.92s/it]

# %%
rnn150k=rnn_sample150k.copy()

# %%
rnn150k
cols=list(map(str, range(0,9)))
rnn150k.columns = cols
rnn150k=rnn150k.drop(['4','5','6','7','8'],axis=1)
rnn150k
# Out:
#                   0            1            2            3
# 0       30101100401  30103102031  30101100401            0
# 1       30402108629  30402108714  30402108629  30402108629
# 2       30202102702  30501110531  30202102702            0
# 3       30501110519  30501111030  30501110804  30501111206
# 4       30303106020  30503112806  30303106020  30303106321
# ...             ...          ...          ...          ...
# 149995  30101100116  30101100407  30101100116  30103102031
# 149996  30501110531  30303106032            0            0
# 149997  30101100423  30101100437  30101100423            0
# 149998  30101100324  30102100728  30101100324            0
# 149999  30102101230  30102101242  30102101333  30102101230
#
# [150000 rows x 4 columns]

# %%
rnn150k.to_csv('/Users/erensmacbook/downloads/rnn150k.csv')

# %%
rnn50k= pd.read_csv('/Users/erensmacbook/Downloads/rnn50k.csv',index_col=0)
